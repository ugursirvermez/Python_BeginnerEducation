# %% [markdown]
# #Çalıştığım Sunucunun Bilgileri

# %%
# !nvidia-smi
# Out:
# Sat Dec 14 10:10:00 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# #Python İlk Kod
# Python'a giriş dersinde ilk olarak bilgisayara yazı yazdırıyoruz!

# %%
print("HELLO WORLD!")
# Out:
# HELLO WORLD!

# %%
print(2+8)
# Out:
# 10

# %%
print(str(2)+""+str(8))
# Out:
# 28

# %% [markdown]
# **String:** Metin değişkenleri anlamına gelir. "" (Çift Tırnak) işareti arasına yazılır. Sayıları metine dönüştürürken str(sayi) içine yazarız.
#
# **Integer:** Sayı değişkenleri anlamına gelir. Sadece sayının kendisi yazılır. Sayıya çevirmek için int(sayi) yazarız.

# %%
print(len("MATEMATIK"))
# Out:
# 9

# %% [markdown]
# **Not-1:** Sayıları metinlere çevirebilirim ancak metinleri sayıya çeviremem.
#
# **Not-2:** Metinlerin harf sayısını(uzunluğunu) öğrenebilirim.
#
# **len():** Parantez içine çift tırnakla bir yazı yazarsam bana harf sayısını verir.

# %%
print(23+9)
print(23-9)
print(23*9)
print(23/9)
# Out:
# 32
# 14
# 207
# 2.5555555555555554

# %%
print((23+9),(23-9),(23*9),(23/9))
print((23+9)+(23-9)+(23*9)+(23/9))
# Out:
# 32 14 207 2.5555555555555554
# 255.55555555555554

# %%
print("Merhaba ben", "Haşmet Dayı", "Yapay zekasıyım.")
print("Size radyoaktif "+"Bir ürün getirmekteyim"+"Size nasıl yardımcı olabilirim?")
# Out:
# Merhaba ben Haşmet Dayı Yapay zekasıyım.
# Size radyoaktif Bir ürün getirmekteyimSize nasıl yardımcı olabilirim?

# %%
print("Haşmet Dayı'dan günün menüsü: \n"+"Kuru Fasulye ve Pilav \n"+"THE AYRAN")
# Out:
# Haşmet Dayı'dan günün menüsü:
# Kuru Fasulye ve Pilav
# THE AYRAN

# %%
print("Albert Einstein")
# Out:
# Albert Einstein

# %% [markdown]
# UNUTMA NOT EKLENECEK

# %% [markdown]
# #ÖDEVLER
#
#
# 1.   Kendinizi tanıtan bir print yazısı yazın:
#      (Ad, soyad, kişisel bilgiler vs.)
# 2.   Print komutunda sayıları topla, çıkar, çarpma ve bölme
# 3.   Ailenizdeki kişileri \n ile alt alta yazıyorsunuz.
# 4.   Bugün ki yaşınızın 5 yıl öncesindeki yaşınızı matematiksel olarak yaz.
# 5.   Haşmet Dayı Restoran zincirine salı günü menüsünü yan yana yaz.
